# %%
import pandas
import matplotlib.pyplot as plt
# %matplotlib inline

data = pandas.read_csv("C:\\Users\\mysti\\Coding\\GoToCode\\AWEFH.csv")

# %%
data.head()
# Out:
#    1262  PASS  2.83
# 0  1263  PASS  2.83
# 1  1264  PASS  2.83
# 2  1265  PASS  2.83
# 3  1266  PASS  2.83
# 4  1267  PASS  2.83

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
data.plot(color = 'plum')
# Out:
# <AxesSubplot:>

# %%
data.plot(color = 'plum', figsize =(10, 4))
# Out:
# <AxesSubplot:>

# %%
data.plot(colormap = "Pastel1", figsize =(10, 4))
# Out:
# <AxesSubplot:>

# %%
import pandas
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

data1 = pandas.read_csv("C:\\Users\\mysti\\Coding\\GoToCode\\AWEFH.csv")

# %%
sns.countplot(x='PASS', data = data1)
# Out:
# <AxesSubplot:xlabel='PASS', ylabel='count'>

# %%
sns.countplot(x='PASS', data = data1, hue = '2.83')
# Out:
# <AxesSubplot:xlabel='PASS', ylabel='count'>
